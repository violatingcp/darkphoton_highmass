# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm

# %%
def ylhc():
    pId=0
    x = np.linspace(0,0,27)
    y = np.linspace(0,0,27)
    x[pId] = 3.2058453875896658; y[pId] = 0.00000327972253637836; pId+=1;
    x[pId] = 4.245271016529975; y[pId] = 0.000003794770540045739; pId+=1;
    x[pId] = 5.916289459971042; y[pId] = 0.000004390701741343217; pId+=1;
    x[pId] = 7.703453362224044; y[pId] = 0.000003794770540045739; pId+=1;
    x[pId] = 10.030861385456202; y[pId] = 0.000003049038413792961; pId+=1;
    x[pId] = 13.509926059807018; y[pId] = 0.000004233473373160471; pId+=1;
    x[pId] = 19.157605755791305; y[pId] = 0.0000025408403378235663; pId+=1;
    x[pId] = 23.30922707928778; y[pId] = 0.0000012707859313704527; pId+=1;
    x[pId] = 26.053317512088718; y[pId] = 3.81459085961719e-7; pId += 1;
    x[pId] = 27.438075307559323; y[pId] = 9.896351520391574e-8; pId += 1;
    x[pId] = 28.16839136907388; y[pId] = 2.4755126980527937e-8; pId+=1;
    x[pId] = 29.92781249792488; y[pId] = 3.7165137731350808e-9; pId += 1;
    x[pId] = 31.46634410666328; y[pId] = 2.218982341458988e-8; pId+=1;
    x[pId] = 32.806069386277386; y[pId] = 1.145047569938286e-7; pId+=1;
    x[pId] = 36.6208967782811; y[pId] = 3.956262211548881e-7; pId+=1;
    x[pId] = 40.189262427076976; y[pId] = 0.0000013669310426442051; pId+=1;
    x[pId] = 46.42900083836446; y[pId] = 0.0000028345797992567095; pId+=1;
    x[pId] = 59.40951723431218; y[pId] = 0.000005268893945666225; pId+=1;
    x[pId] = 77.99891424651229; y[pId] = 0.0000070536887085989; pId+=1;
    x[pId] = 111.51024238657372; y[pId] = 0.000008464509757381337; pId+=1;
    x[pId] = 170.62088269123018; y[pId] = 0.00001462710473306867; pId+=1;
    x[pId] = 254.46844982881703; y[pId] = 0.000028198515414855245; pId+=1;
    x[pId] = 373.08563951697477; y[pId] = 0.00006289882520006936; pId+=1;
    x[pId] = 537.6989924092812; y[pId] = 0.00017461495966248044; pId+=1;
    x[pId] = 687.9216804444691; y[pId] = 0.00043451927853527565; pId+=1;
    x[pId] = 879.9272508406884; y[pId] = 0.0016148968833690574; pId+=1;
    x[pId] = 1078.6659711618488; y[pId] = 0.005579642001742669; pId+=1;
    return x,y

def yhllhc():
    pId=0
    x = np.linspace(0,0,20)
    y = np.linspace(0,0,20)
    x[pId] = 3.3793615113078492; y[pId] = 1.4780300298478112e-7; pId += 1;
    x[pId] = 5.041038943761223; y[pId] = 1.9787006229424717e-7; pId += 1;
    x[pId] = 7.650081790243514; y[pId] = 1.9787006229424717e-7; pId += 1;
    x[pId] = 10.219220893352231; y[pId] = 1.5329230761089157e-7; pId += 1;
    x[pId] = 14.240875458154052; y[pId] = 1.9787006229424717e-7; pId += 1;
    x[pId] = 19.353405109104955; y[pId] = 1.1040441104644187e-7; pId += 1;
    x[pId] = 24.786612530432645; y[pId] = 3.6972030545321874e-8; pId += 1;
    x[pId] = 27.469798872561483; y[pId] = 1.1098106006538676e-8; pId += 1;
    x[pId] = 29.977998691640426; y[pId] = 1.5570684047537412e-10; pId += 1;
    x[pId] = 33.4214580748449; y[pId] = 5.97060168994657e-9; pId += 1;
    x[pId] = 39.243905087858; y[pId] = 5.133425218824546e-8; pId += 1;
    x[pId] = 49.35275078810639; y[pId] = 1.710140035432055e-7; pId += 1;
    x[pId] = 68.76700058990991; y[pId] = 2.7473502343522245e-7; pId += 1;
    x[pId] = 101.71312262135643; y[pId] = 3.5462859845210176e-7; pId += 1;
    x[pId] = 168.02199272555242; y[pId] = 6.128163118220572e-7; pId += 1;
    x[pId] = 263.69315309883626; y[pId] = 0.000001470350299935512; pId += 1;
    x[pId] = 383.31118536576247; y[pId] = 0.000003658882106991576; pId +=1;
    x[pId] = 591.3555535940118; y[pId] = 0.000010534754864987925; pId += 1;
    x[pId] = 1001.0790669425601; y[pId] = 0.0001352763010214231; pId += 1;
    x[pId] = 1156.3050078971955; y[pId] = 0.0003894912786558098; pId += 1;
    return x,y

def LLSF(): 
    pId=0
    x = np.linspace(0,0,23)
    y = np.linspace(0,0,23)
    x[pId] = 5.0;   y[pId] = 1.0; pId += 1;
    x[pId] = 10.0;  y[pId] = 0.5; pId += 1;
    x[pId] = 15.0;  y[pId] = 0.1; pId += 1;
    x[pId] = 20.0;  y[pId] =  0.02776381899783627; pId += 1;
    x[pId] = 25.0;  y[pId] =  0.004782771482380706; pId += 1;
    x[pId] = 30.0;  y[pId] =  0.009260613299413276; pId += 1;
    x[pId] = 40.0;  y[pId] =  0.0109520492621046; pId += 1;
    x[pId] = 50.0;  y[pId] =  0.014265064190294196; pId += 1;
    x[pId] = 60.0;  y[pId] =  0.018734485684611165; pId += 1;
    x[pId] = 75.0;  y[pId] =  0.02075623472617766; pId += 1;
    x[pId] = 80.0;  y[pId] =  0.023836438454860144; pId += 1;
    x[pId] = 90.0;  y[pId] =  0.023861088186074936; pId += 1;
    x[pId] = 100.0;  y[pId] =  0.02748665884207635; pId += 1;
    x[pId] = 110.0;  y[pId] =  0.031164985793668713; pId += 1;
    x[pId] = 125.0;  y[pId] =  0.03776089305485922; pId += 1;
    x[pId] = 175.0;  y[pId] =  0.05985367861601341; pId += 1;
    x[pId] = 200.0;  y[pId] =  0.05488761288296602; pId += 1;
    x[pId] = 250.0;  y[pId] =  0.07086788846744418; pId += 1;
    x[pId] = 400.0;  y[pId] =  0.14628781958358344; pId += 1;
    x[pId] = 500.0;  y[pId] =  0.13074924247151745; pId += 1;
    x[pId] = 600.0;  y[pId] =  0.16063972364639775; pId += 1;
    x[pId] = 1000.0;  y[pId] =  0.49511397563280435; pId += 1;
    x[pId] = 1500.0;  y[pId] =  0.6457660846409317; pId += 1;
    y = np.minimum(1,np.sqrt(10)*y) # reduce cross section sensitivity by 10 just to be conservative
    return x,y
    
def epsilon(iVal):
    return np.sqrt(iVal*(4*3.1415)*(3**4))

def mjcoupl(iGQ0,iGDM0,iGDM):
    lVal=iGQ0*iGDM0*iGDM
    pVal=(iGDM*iGDM*iGDM0*iGDM0+15*(iGDM-iGDM0)*(iGDM+iGDM0)*iGQ0*iGQ0)                                                                                                                                                                                                                         
    if pVal  < 0:
        return 1
    lVal=lVal/np.sqrt(pVal)
    return lVal

def alpha05():
    return mjcoupl(0.01,np.sqrt(4*3.14159*0.1),np.sqrt(4*3.14159*0.5))/0.01

# %%
xvlhc,yvlhc = ylhc()
xvhllhc,yvhllhc = yhllhc()

#going from alphaD=0.1=>0.5, y gets scaled by 5 and Gamma_{alpha5} = 5 Gamma => multiply by 25 
plt.plot(xvlhc,yvlhc,label='lhc',c='red')
plt.plot(xvhllhc,yvhllhc,label='hl-lhc',c='orange')
plt.plot(xvlhc,yvlhc*25,label='lhc(alpha$_{D}$=0.5)',c='red',linestyle='--')
plt.plot(xvhllhc,yvhllhc*25,label='hl-lhc(alpha$_{D}$=0.5)',c='green',linestyle='--')

plt.xlabel("m$_{dm}$ (GeV)")
plt.ylabel("y")
plt.legend()
plt.xscale('log')
plt.xlim((0,2000))
plt.ylim((1e-10,0.3))
plt.yscale('log')
plt.show()
# Out:
# /Users/pharris/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:14: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.

# %%
epsvlhc = epsilon(yvlhc)
epsvhllhc = epsilon(yvhllhc)
xllsf,yllsf = LLSF()

#plt.plot(xllsf,yllsf)

from scipy import interpolate
def scale(iX,iY,iXInt,iYInt):
    tck = interpolate.splrep(iXInt, iYInt) #setup the spline
    scaleout = interpolate.splev(iX, tck)
    yout=iY*scaleout
    return yout

epsvlhcll = scale(xvlhc,epsvlhc,xllsf,yllsf)
epsvhllhcll = scale(xvhllhc,epsvhllhc,xllsf,yllsf)
    
plt.plot(xvlhc,epsvlhc,label='lhc',c='red')
plt.plot(xvhllhc,epsvhllhc,label='hl-lhc',c='orange')
plt.plot(xvlhc,epsvlhcll,label='lhc(+secondary vertex)',c='red',linestyle='--')
plt.plot(xvhllhc,epsvhllhcll,label='hl-lhc(+secondary vertex)',c='orange',linestyle='--')

plt.xlabel("m$_{dm}$ (GeV)")
plt.ylabel("$\epsilon$")
plt.legend()
plt.xscale('log')
plt.xlim((0,2000))
plt.ylim((1e-5,0.3))
plt.yscale('log')
plt.show()
# Out:
# /Users/pharris/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:26: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.

# %%
def sinInv(): 
    pId=0
    x = np.linspace(0,0,3)
    y = np.linspace(0,0,3)
    x[pId] = 0.0001; y[pId] = 0.000081; pId+=1;
    x[pId] = 0.001;  y[pId] = 0.0081; pId+=1;
    x[pId] = 0.01;   y[pId] = 0.751;   pId+=1;
    #x[pId] = 0.1;    y[pId] = 0.8862209;    pId+=1;
    return x,y

x,y=sinInv()
plt.plot(x,y,label='exp',c='black')
plt.legend()
#plt.xlim((0,2000))
#plt.ylim((1e-2,0.3))
plt.xscale('log')
plt.yscale('log')
plt.show()

from scipy.interpolate import interp1d
hinv = interp1d(y, x)
print(hinv(0.1))
# Out:
# 0.0021133396150222108

# %%
def kinScale(iM):
    return (1.-4*(iM/125.)**2)**1.5

def makeVals(iXmin,iXmax,iVal):
    pN=30
    pId=0
    x = np.linspace(0,0,2*pN)
    y = np.linspace(0,0,2*pN)
    for i0 in range(pN):
        x[i0]=i0*(iXmax-iXmin)/(pN-2)
        scale=kinScale(x[i0])
        if np.isnan(scale):
            y[i0]=(iVal**2)*1e4
        else:
            y[i0]=np.minimum((iVal**2)/scale,(iVal**2)*1e4)       
    for i0 in range(pN):
        x[i0+pN]=x[pN-i0-1]
        y[i0+pN]=1        
    return x,y

def makeCoupl(iXmin,iXmax,iVal):
    pN=30
    pId=0
    x = np.linspace(0,0,2*pN)
    y = np.linspace(0,0,2*pN)
    for i0 in range(pN):
        x[i0]=i0*(iXmax-iXmin)/(pN-2)
        y[i0]=(iVal**2)
    return x,y

#sinX=hinv(0.01)
#x01,y01=makeVals(0,200,hinv(np.sqrt(1-0.01*0.01)))
x01,y01=makeVals(0,220,hinv(0.07))
x02,y02=makeVals(0,220,hinv(0.04))

def makeVals(iXmin,iXmax,iVal):
    pN=30
    pId=0
    x = np.linspace(0,0,2*pN)
    y = np.linspace(0,0,2*pN)
    for i0 in range(pN):
        x[i0]=i0*(iXmax-iXmin)/(pN-2)
        scale=kinScale(x[i0]/3.)
        #scale=kinScale(x[i0])
        if np.isnan(scale):
            y[i0]=(iVal**2)*1e4
        else:
            y[i0]=np.minimum((iVal**2)/scale,(iVal**2)*1e4)       
    for i0 in range(pN):
        x[i0+pN]=x[pN-i0-1]
        y[i0+pN]=1000000        
    return x,y

def makeCoupl(iXmin,iXmax,iVal):
    pN=30
    pId=0
    x = np.linspace(0,0,2*pN)
    y = np.linspace(0,0,2*pN)
    for i0 in range(pN):
        x[i0]=i0*(iXmax-iXmin)/(pN-2)
        y[i0]=(iVal**2)
    return x,y

#sinX=hinv(0.01)
#x01,y01=makeVals(0,200,hinv(np.sqrt(1-0.01*0.01)))
xc01,yc01=makeCoupl(0,220,np.arccos(1-0.07))
xc02,yc02=makeCoupl(0,220,np.arccos(1-0.04))
xc03,yc03=makeCoupl(0,220,np.arccos(1-0.005))
print(np.arccos(1-0.005))

x01,y01=makeVals(0,220,hinv(0.1))
x02,y02=makeVals(0,220,hinv(0.024))
x03,y03=makeVals(0,220,hinv(0.005))
x04,y04=makeVals(0,220,hinv(0.0001))

plt.fill(x01*(1./3.),y01,label='BR(h$\chi\chi$)=10%',alpha=0.2)
plt.fill(x02*(1./3.),y02,label='HL-LHC',alpha=0.2)
plt.fill(x03*(1./3.),y03,label='FCC-ee',alpha=0.2)
plt.fill(x04*(1./3.),y04,label='FCC-hh',alpha=0.2)
l2=plt.plot(xc01,yc01,label='LHC (coupling)')
l3=plt.plot(xc03,yc03,label='FCC-ee(coupling)')
plt.legend()
plt.xlim((0,220/3))
plt.ylim((1e-10,1e-3))
plt.yscale('log')
plt.xlabel("m$_{\chi}$(GeV)")
plt.ylabel("$\Theta^{2}$")
plt.savefig("higgs_portal.pdf")

plt.show()
# Out:
# /Users/pharris/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
# 0.10004171361154007

# %%
def rescale(iY):
    outval=iY*((1./3.)**4)*(0.000511/246)**2
    return outval

y01dm=rescale(y01)
y02dm=rescale(y02)
y03dm=rescale(y03)
y04dm=rescale(y04)
yc01dm=rescale(yc01)
yc03dm=rescale(yc03)
print(rescale(3.25*4*1e-5))

plt.fill(x01,y01dm,label='BR(h$\chi\chi$)=10%',alpha=0.2)
plt.fill(x02,y02dm,label='HL-LHC',alpha=0.2)
plt.fill(x03,y03dm,label='FCC-ee',alpha=0.2)
plt.fill(x04,y04dm,label='FCC-hh',alpha=0.2)
l2=plt.plot(xc01,yc01dm,label='LHC (coupling)')
l3=plt.plot(xc03,yc03dm,label='FCC-ee(coupling)')
plt.legend()
plt.xlim((0,220))
plt.ylim((1e-24,1e-9))
plt.yscale('log')
plt.xlabel("m$_{\phi}$(GeV)")
plt.ylabel("$\kappa_{e}=(g_{\chi}g_{e})^{2}(m_{\chi}/m_{\phi})^{4}$")
plt.savefig("higgs_portal.pdf")

plt.show()
# Out:
# 6.925161716236252e-18
